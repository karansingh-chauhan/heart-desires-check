# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df=pd.read_csv("D:\\machine learning projecsts folders\\hearth desese\\train.csv")
test_df=pd.read_csv("D:\\machine learning projecsts folders\\hearth desese\\test.csv")

# %%
sns.set_theme(style="whitegrid")

# %%
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# %%
train_df.head()
# Out:
#    id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   0   58    1                4  152          239             0            0
# 1   1   52    1                1  125          325             0            2
# 2   2   56    0                2  160          188             0            2
# 3   3   44    0                3  134          229             0            2
# 4   4   58    1                4  140          234             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     158                1            3.6            2
# 1     171                0            0.0            1
# 2     151                0            0.0            1
# 3     150                0            1.0            2
# 4     125                1            3.8            2
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        2         7      Presence
# 1                        0         3       Absence
# ...

# %% [markdown]
# age vs sex

# %%
sns.catplot(train_df,x='Sex',y='Age')

# %%
sns.boxplot(train_df,x='Sex',y='Age')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.barplot(train_df,x='Sex',y='Age',estimator=np.mean)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# observation :
# 1. the age and sex comparisoimn is almost same with slight diffrence btween number

# %%
train_df.sample(3)
# Out:
#             id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 195040  195040   54    0                4  110          243             0
# 480991  480991   44    1                4  120          267             0
# 209593  209593   42    1                4  130          302             0
#
#         EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# 195040            0     162                0            0.0            2
# 480991            2     108                0            0.0            1
# 209593            2     108                1            0.0            2
#
#         Number of vessels fluro  Thallium Heart Disease
# 195040                        0         3      Presence
# 480991                        1         7      Presence
# 209593                        0         7      Presence

# %%
sns.catplot(train_df,x='Chest pain type',y='Age')

# %% [markdown]
# sex vs chest pain type

# %%
pd.crosstab(train_df['Sex'],train_df['Chest pain type']).plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
pd.crosstab(train_df['Sex'],train_df['Heart Disease']).plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# observation:
# 1. there i more number of present of hd in males as compare to female
# 2. ther are more men with type 4 cgest pain as compare to female

# %%
train_df.sample()
# Out:
#             id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 348588  348588   55    1                4  108          229             0
#
#         EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# 348588            2      95                1            0.0            1
#
#         Number of vessels fluro  Thallium Heart Disease
# 348588                        0         3      Presence

# %%
pd.crosstab(train_df['Chest pain type'],train_df['Heart Disease']).plot(kind='bar')
# Out:
# <Axes: xlabel='Chest pain type'>

# %% [markdown]
# observation:
# 1. it is clear that person with type 4 chest pain has more chance of having hd
# 2. person with 1,2 3 have more chance of not havin g hd

# %%
train_df.sample()
# Out:
#             id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 253090  253090   44    1                3  140          219             0
#
#         EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# 253090            0     142                0            0.1            1
#
#         Number of vessels fluro  Thallium Heart Disease
# 253090                        0         7       Absence

# %% [markdown]
# cholestroll vs hd

# %%
sns.catplot(train_df,x='Heart Disease',y='Cholesterol')

# %%
sns.boxplot(train_df,x='Heart Disease',y='Cholesterol')
# Out:
# <Axes: xlabel='Heart Disease', ylabel='Cholesterol'>

# %%
train_df.sample()
# Out:
#             id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 262341  262341   63    1                4  120          254             0
#
#         EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# 262341            0     172                0            0.6            1
#
#         Number of vessels fluro  Thallium Heart Disease
# 262341                        0         7      Presence

# %%
pd.crosstab(train_df['FBS over 120'],train_df['Heart Disease']).plot(kind='bar')
# Out:
# <Axes: xlabel='FBS over 120'>

# %% [markdown]
# person with fbs low have more chnce of having no hd

# %%
sns.scatterplot(x=train_df['BP'],y=train_df['Cholesterol'])
# Out:
# <Axes: xlabel='BP', ylabel='Cholesterol'>

# %% [markdown]
# thre are some point with oultier which can be deleted

# %%
sns.scatterplot(x=train_df['Age'],y=train_df['BP'])
# Out:
# <Axes: xlabel='Age', ylabel='BP'>

# %%
sns.heatmap(pd.crosstab(train_df['EKG results'],train_df['Heart Disease']),annot=True,fmt='0.2f')
# Out:
# <Axes: xlabel='Heart Disease', ylabel='EKG results'>

# %% [markdown]
# the person who have type 2 have more chnce of havin g hd as compare to 0 and 1

# %%
sns.catplot(x=train_df['Sex'],y=train_df['Max HR'])

# %%
sns.catplot(x=train_df['Heart Disease'],y=train_df['Max HR'])

# %% [markdown]
# observation:
# 1. the max hr less than 100 have more chance not to have hd

# %%
pd.crosstab(train_df['Exercise angina'],train_df['Heart Disease']).plot(kind='bar')
# Out:
# <Axes: xlabel='Exercise angina'>

# %% [markdown]
# the person with 0 exercise agin have more chance to get safe as compare to 1

# %%
sns.catplot(y=train_df['ST depression'],x=train_df['Heart Disease'])

# %% [markdown]
# person with st depresion above 6 hacve more chance to get hd

# %%
sns.heatmap(pd.crosstab(train_df['Slope of ST'],train_df['Heart Disease']),annot=True,fmt='0.2f')
# Out:
# <Axes: xlabel='Heart Disease', ylabel='Slope of ST'>

# %% [markdown]
# person with the slope diffrence of 2 and 3 are more likly to make hd

# %%
pd.crosstab(train_df['Number of vessels fluro'],train_df['Heart Disease']).plot(kind='bar')
# Out:
# <Axes: xlabel='Number of vessels fluro'>

# %% [markdown]
# person having mpre than 0 are more likkly ot have hd

# %%
pd.crosstab(train_df['Thallium'],train_df['Heart Disease']).plot(kind='bar')
# Out:
# <Axes: xlabel='Thallium'>

# %% [markdown]
# person with 7 and 6 are more likly to have thalium

# %%
train_df['Heart Disease']=train_df['Heart Disease'].map({'Presence':1,'Absence':0})

# %%
train_df['Heart Disease'].value_counts()
# Out:
# Heart Disease
# 0    347546
# 1    282454
# Name: count, dtype: int64

# %%
sns.boxplot(train_df['BP'])
# Out:
# <Axes: ylabel='BP'>

# %%
sns.boxplot(train_df['Cholesterol'])
# Out:
# <Axes: ylabel='Cholesterol'>

# %%
plt.figure(figsize=(15,10))
sns.heatmap(train_df.corr(),annot=True)
plt.show()

# %%
sns.pairplot(train_df)

# %%
train_df.sample()
# Out:
#             id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  \
# 489074  489074   50    0                4  128          177             0
#
#         EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# 489074            2     163                0            0.0            1
#
#         Number of vessels fluro  Thallium  Heart Disease
# 489074                        0         3              0
